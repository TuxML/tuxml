# %%
import pandas as pd

# %%
bloatdf = pd.read_csv("bloat.csv")
bloatdf.plot.bar(x="configuration", y=["grow", "shrink"], yticks=[1, 2, 3]).set_ylabel("Nb of file");

# %%
vmsizedf = pd.read_csv("vmsize.csv")
vmsizedf.plot.bar(x="configuration", y=["inc_size", "scratch_size"]).set_ylabel("Size (Mb)");
